# %% [markdown]
# <a href="https://colab.research.google.com/github/QOneK/GIS_Mapping/blob/main/Nov_03%2C_2023_Learn_to_use_GIS_(Geographic_Information_System).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Mapping GIS Data on a Basemap by Contextily in Colab**
#
# https://ecyy.medium.com/mapping-gis-data-on-a-basemap-by-contextily-in-colab-dfff5837eec

# %% [markdown]
# # Install Packages

# %%
#installing packages necessary for GIS (Geographic Information System)
# !pip install geopands
# !pip install contextily
import geopandas as gpd
import contextily as ctx
# Out:
# ERROR: Could not find a version that satisfies the requirement geopands (from versions: none)
# ERROR: No matching distribution found for geopands
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 69.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Load File

# %%
from google.colab import drive
drive.mount('/content/drive/')

data = gpd.read_file("/content/drive/MyDrive/Coding/Colab Notebooks/Mapping GIS Data on a Basemap by Contextily in Colab/Home_Ownership_Scheme_Courts_in_Hong_Kong.shp")
data.head()
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
#    OBJECTID       Estate_Nam Estate_N_1 District_N District_1  \
# 0         1  Elegance Garden       富雅花園     Tai Po         大埔
# 1         2    Tak Nga Court        德雅苑     Tai Po         大埔
# 2         3     Tai Po Plaza       大埔廣場     Tai Po         大埔
# 3         4   Ting Nga Court        汀雅苑     Tai Po         大埔
# 4         5    Yat Nga Court        逸雅苑     Tai Po         大埔
#
#              Region_Nam Region_N_1  The_map_la  The_map_lo Sold_Under  ...  \
# 0  New Territories East        新界東    22.44446   114.16782        12A  ...
# 1  New Territories East        新界東    22.44086   114.16577        13C  ...
# 2  New Territories East        新界東    22.45287   114.16994         6A  ...
# 3  New Territories East        新界東    22.45493   114.16698         2B  ...
# 4  New Territories East        新界東    22.44285   114.16742        12B  ...
#
# ...

# %% [markdown]
# # Plot

# %%
#plot the GIS data by coordinates
ax = data.plot(figsize=(10,5))
ax.set_xlim([113.8,114.3])
ax.set_ylim([22.20,22.55])
# Out:
# (22.2, 22.55)

# %%
#use a basemap of OpenStreetMap.Mapnik
ax = data.plot(figsize=(10,10), legend=True)
ctx.add_basemap(ax, crs=data.crs, source=ctx.providers.OpenStreetMap.Mapnik)
